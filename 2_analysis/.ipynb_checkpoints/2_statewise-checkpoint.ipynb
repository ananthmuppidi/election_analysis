# %%
import pandas as pd 
import numpy as np
import json

# %%
path = "../assets/map_data/states_india.geojson"
india_states = json.load(open(path, 'r'))

# %%
df = pd.read_csv("../assets/data/cleaned_data.csv")
df.drop(axis=1,columns="Unnamed: 0", inplace=True)
state_mapping = {
    'Andaman_&_Nicobar_Islands': 'Andaman & Nicobar Island',
    'Andhra_Pradesh': 'Andhra Pradesh',
    'Arunachal_Pradesh': 'Arunanchal Pradesh',
    'Assam': 'Assam',
    'Bihar': 'Bihar',
    'Chandigarh': 'Chandigarh',
    'Chhattisgarh': 'Chhattisgarh',
    'Dadra_&_Nagar_Haveli': 'Dadara & Nagar Havelli',
    'Daman_&_Diu': 'Daman & Diu',
    'Delhi': 'NCT of Delhi',
    'Goa': 'Goa',
    'Gujarat': 'Gujarat',
    'Haryana': 'Haryana',
    'Himachal_Pradesh': 'Himachal Pradesh',
    'Jammu_&_Kashmir': 'Jammu & Kashmir',
    'Jharkhand': 'Jharkhand',
    'Karnataka': 'Karnataka',
    'Kerala': 'Kerala',
    'Lakshadweep': 'Lakshadweep',
    'Madhya_Pradesh': 'Madhya Pradesh',
    'Maharashtra': 'Maharashtra',
    'Manipur': 'Manipur',
    'Meghalaya': 'Meghalaya',
    'Mizoram': 'Mizoram',
    'Nagaland': 'Nagaland',
    'Odisha': 'Odisha',
    'Puducherry': 'Puducherry',
    'Punjab': 'Punjab',
    'Rajasthan': 'Rajasthan',
    'Sikkim': 'Sikkim',
    'Tamil_Nadu': 'Tamil Nadu',
    'Telangana': 'Telangana',
    'Tripura': 'Tripura',
    'Uttar_Pradesh': 'Uttar Pradesh',
    'Uttarakhand': 'Uttarakhand',
    'West_Bengal': 'West Bengal',
    'Dadra & Nagar Haveli And Daman & Diu': 'Daman & Diu',
    'Goa,_Daman_&_Diu': 'Goa',
    'Mysore': 'Karnataka',  # Assuming "Mysore" should be mapped to "Karnataka" as there's no separate entry for it
    'Madras': 'Tamil Nadu'  # Assuming "Madras" should be mapped to "Tamil Nadu" as there's no separate entry for it
}


df["State"] = df["State_Name"].map(state_mapping)

# %%
state_id_map = {}
for feature in india_states['features']:
    feature['id'] = feature['properties']['state_code']
    state_id_map[feature['properties']['st_nm']] = feature['id']

# %%
df['id'] = df['State'].apply(lambda x: state_id_map[x])

# %%
df["State"].unique()
# Out:
# array(['Andaman & Nicobar Island', 'Andhra Pradesh', 'Arunanchal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadara & Nagar Havelli', 'Daman & Diu', 'NCT of Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %%
#Reading the shape file
fp = r'../assets/map_data/india-polygon.shp'
map_df = gpd.read_file(fp)
map_df.head()
# Out:
#    id                        st_nm  \
# 0 NaN  Andaman and Nicobar Islands
# 1 NaN            Arunachal Pradesh
# 2 NaN                        Assam
# 3 NaN                        Bihar
# 4 NaN                   Chandigarh
#
#                                             geometry
# 0  MULTIPOLYGON (((93.84831 7.24028, 93.92705 7.0...
# 1  POLYGON ((95.23643 26.68105, 95.19594 27.03612...
# 2  POLYGON ((95.19594 27.03612, 95.08795 26.94578...
# 3  POLYGON ((88.11357 26.54028, 88.28006 26.37640...
# 4  POLYGON ((76.84208 30.76124, 76.83758 30.72552...

# %%
df = pd.read_csv("../assets/data/cleaned_data.csv")

# %%
df["State_Name"].unique()
# Out:
# array(['Andaman_&_Nicobar_Islands', 'Andhra_Pradesh', 'Arunachal_Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra_&_Nagar_Haveli', 'Daman_&_Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal_Pradesh', 'Jammu_&_Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya_Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil_Nadu', 'Telangana', 'Tripura', 'Uttar_Pradesh',
#        'Uttarakhand', 'West_Bengal',
#        'Dadra & Nagar Haveli And Daman & Diu', 'Goa,_Daman_&_Diu',
#        'Mysore', 'Madras'], dtype=object)

# %%
map_df["st_nm"].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Arunachal Pradesh', 'Assam',
#        'Bihar', 'Chandigarh', 'Chhattisgarh', 'Dadra and Nagar Haveli',
#        'Daman and Diu', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Delhi', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Odisha', 'Andhra Pradesh',
#        'Jammu and Kashmir', 'Ladakh'], dtype=object)

# %%
# Assuming 'data_df' is your DataFrame containing the data with the original state names

# Create a dictionary to map the old state names to the new state names
state_name_mapping = {
    'Andaman_&_Nicobar_Islands': 'Andaman and Nicobar Islands',
    'Arunachal_Pradesh': 'Arunachal Pradesh',
    'Assam': 'Assam',
    'Bihar': 'Bihar',
    'Chandigarh': 'Chandigarh',
    'Chhattisgarh': 'Chhattisgarh',
    'Dadra_&_Nagar_Haveli': 'Dadra and Nagar Haveli',
    'Daman_&_Diu': 'Daman and Diu',
    'Delhi': 'Delhi',
    'Goa': 'Goa',
    'Gujarat': 'Gujarat',
    'Haryana': 'Haryana',
    'Himachal_Pradesh': 'Himachal Pradesh',
    'Jammu_&_Kashmir': 'Jammu and Kashmir',
    'Jharkhand': 'Jharkhand',
    'Karnataka': 'Karnataka',
    'Kerala': 'Kerala',
    'Lakshadweep': 'Lakshadweep',
    'Madhya_Pradesh': 'Madhya Pradesh',
    'Maharashtra': 'Maharashtra',
    'Manipur': 'Manipur',
    'Meghalaya': 'Meghalaya',
    'Mizoram': 'Mizoram',
    'Nagaland': 'Nagaland',
    'Odisha': 'Odisha',
    'Puducherry': 'Puducherry',
    'Punjab': 'Punjab',
    'Rajasthan': 'Rajasthan',
    'Sikkim': 'Sikkim',
    'Tamil_Nadu': 'Tamil Nadu',
    'Telangana': 'Telangana',
    'Tripura': 'Tripura',
    'Uttar_Pradesh': 'Uttar Pradesh',
    'Uttarakhand': 'Uttarakhand',
    'West_Bengal': 'West Bengal',
    'Dadra & Nagar Haveli And Daman & Diu': 'Dadra and Nagar Haveli',
    'Goa,_Daman_&_Diu': 'Goa',
    'Mysore': 'Karnataka',
    'Madras': 'Tamil Nadu'
}

# Replace the old state names with the new state names using the mapping dictionary
df['State_Name'] = df['State_Name'].replace(state_name_mapping)

# %%
margin_df = df.groupby('State_Name')['Margin_Percentage'].mean().reset_index()
margin_df = margin_df.rename(columns={'Margin_Percentage': 'Average_Margin'})
margin_df
# Out:
#                      State_Name  Average_Margin
# 0   Andaman and Nicobar Islands        5.773966
# 1                Andhra_Pradesh        4.796599
# 2             Arunachal Pradesh       10.653168
# 3                         Assam        5.416224
# 4                         Bihar        3.734431
# 5                    Chandigarh        1.977550
# 6                  Chhattisgarh        3.236471
# 7        Dadra and Nagar Haveli        8.050476
# 8                 Daman and Diu        7.956226
# 9                         Delhi        2.034167
# 10                          Goa        5.186502
# 11                      Gujarat        5.539531
# 12                      Haryana        2.726510
# 13             Himachal Pradesh        7.581056
# 14            Jammu and Kashmir        4.263571
# 15                    Jharkhand        2.625203
# 16                    Karnataka        4.505560
# 17                       Kerala        5.979346
# 18                  Lakshadweep        8.251333
# ...

# %%
merged = map_df.set_index('st_nm').join(margin_df.set_index('State_Name'))

# %%
# create figure and axes for Matplotlib and set the title
fig, ax = plt.subplots(1, figsize=(10, 10))
ax.axis('off')
ax.set_title('Average_Margin', fontdict={'fontsize': '25', 'fontweight' : '10'})

# plot the figure
merged.plot(column='Average_Margin',cmap='YlOrRd', linewidth=0.8, ax=ax, edgecolor='0', legend=True,markersize=[39.739192, -104.990337])
# Out:
# <Axes: title={'center': 'Average_Margin'}>

# %%
merged["id"]
# Out:
# st_nm
# Andaman and Nicobar Islands   NaN
# Arunachal Pradesh             NaN
# Assam                         NaN
# Bihar                         NaN
# Chandigarh                    NaN
# Chhattisgarh                  NaN
# Dadra and Nagar Haveli        NaN
# Daman and Diu                 NaN
# Goa                           NaN
# Gujarat                       NaN
# Haryana                       NaN
# Himachal Pradesh              NaN
# Jharkhand                     NaN
# Karnataka                     NaN
# Kerala                        NaN
# Lakshadweep                   NaN
# Madhya Pradesh                NaN
# Maharashtra                   NaN
# Manipur                       NaN
# Meghalaya                     NaN
# Mizoram                       NaN
# Nagaland                      NaN
# Delhi                         NaN
# Puducherry                    NaN
# Punjab                        NaN
# Rajasthan                     NaN
# Sikkim                        NaN
# ...
